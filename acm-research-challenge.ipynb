# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd 
import functools
import operator 

data = pd.read_csv('../input/acmstardataset/6-class-csv.csv')
mpl.rcParams['font.size'] = 15
mpl.rcParams['axes.labelsize'] = 14

variableName = 'Temperature'
variableName2 = 'Luminosity'

subset = data#.loc[0:1400]
x = subset.sort_values(by=[variableName])[variableName].tolist()
y = subset.sort_values(by=[variableName2])[variableName2].tolist()

plt.figure(figsize=(15,8))
marker_size = 14
plt.scatter(x, y, marker_size, color='#46a5e5')
plt.ylabel("Luminosity", size=12)
plt.xlabel("Temperature", size=12)
plt.draw()

variableName3 = 'Star Type'
variableName4 = 'Spectral Class'

subset = data#.loc[0:1400]
x = subset.sort_values(by=[variableName3])[variableName3].tolist()
y = subset.sort_values(by=[variableName4])[variableName4].tolist()

plt.figure(figsize=(15,8))
marker_size = 14
plt.scatter(x, y, marker_size, color='#46a5e5')
plt.ylabel("Star Type", size=12)
plt.xlabel("Spectral Class", size=12)
plt.draw()

variableName5 = 'Star Color'

subset = data#.loc[0:1400]
x = subset.sort_values(by=[variableName5])[variableName5].tolist()
y = subset.sort_values(by=[variableName4])[variableName4].tolist()

plt.figure(figsize=(15,8))
marker_size = 14
plt.scatter(x, y, marker_size, color='#46a5e5')
plt.ylabel("Star Color", size=12)
plt.xlabel("Spectral Class", size=12)
plt.draw()


O = dataset[dataset["Spectral Class"] == 'O']
B = dataset[dataset["Spectral Class"] == 'B']
A = dataset[dataset["Spectral Class"] == 'A']
F = dataset[dataset["Spectral Class"] == 'F']
G = dataset[dataset["Spectral Class"] == 'G']
K = dataset[dataset["Spectral Class"] == 'K']
M = dataset[dataset["Spectral Class"] == 'M']

plt.style.use('ggplot')

plt.grid()
plt.scatter(np.log(O["Temperature"]), np.log(O["Luminosity"]),10, label = 'O')
plt.scatter(np.log(B["Temperature"]), np.log(B["Luminosity"]),8, label = 'B')
plt.scatter(np.log(A["Temperature"]), np.log(A["Luminosity"]),6, label = 'A')
plt.scatter(np.log(F["Temperature"]), np.log(F["Luminosity"]),4, label = 'F')
plt.scatter(np.log(G["Temperature"]), np.log(G["Luminosity"]),3, label = 'G')
plt.scatter(np.log(K["Temperature"]), np.log(K["Luminosity"]),2, label = 'K')
plt.scatter(np.log(M["Temperature"]), np.log(M["Luminosity"]),1, label = 'M')

plt.gca().invert_xaxis()

plt.title("Hertzsprung-Russell Diagram")
plt.ylabel("Luminosity")
plt.xlabel("Temperature")
plt.legend()
